# %% [markdown]
# # Pandas
#
# reference: pandas.pydata.org
#
# ```python
# import pandas as pd
# ```
#
# Flujo de trabajo: Input data -> ETL -> output data + Analisis

# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '1.5.0'

# %% [markdown]
# ## Input Data
#
# Pandas acepta una gran variedad de ficheros:
# - csv
# - txt
# - hdf
# - excel
# - sql
# - parquet
# - otros
#
# ```python
# # syntax para lectura de datos
# pd.read_<extension>
# ```

# %% [markdown]
# ### read_csv()

# %%
pd.read_csv("example1.csv")
# Out:
#    col1   col2   col3
# 0     1      2      3
# 1     4      5      6
# 2     7      8      9
# 3    10     11     12

# %%
df = pd.read_csv("example1.csv")

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df
# Out:
#    col1   col2   col3
# 0     1      2      3
# 1     4      5      6
# 2     7      8      9
# 3    10     11     12

# %% [markdown]
# **Pandas DataFrame**
#
# - 2 dimensiones: columns and rows
# - Tiene un index para las rows (lineas) y tambien para las columns (columnas)

# %%
# shape (rows, cols)
df.shape
# Out:
# (4, 3)

# %%
print(f"Este DataFrame tiene {df.shape[0]} rows y {df.shape[1]} columns")
# Out:
# Este DataFrame tiene 4 rows y 3 columns

# %%
df.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %% [markdown]
# **example2: sep = ";"**

# %%
df = pd.read_csv("example2.csv")
df
# Out:
#   col1; col2; col3
# 0            1;2;3
# 1            4;5;6

# %%
df.shape
# Out:
# (2, 1)

# %%
df = pd.read_csv("example2.csv",sep=";")
df
# Out:
#    col1   col2   col3
# 0     1      2      3
# 1     4      5      6

# %%
df.shape
# Out:
# (2, 3)

# %% [markdown]
# **example3: otros argumentos**

# %%
df = pd.read_csv("example3.csv", sep=";")
print(df.shape)
df
# Out:
# (3, 3)
#       col1  col2       col3
# 0  Roberto    38     Madrid
# 1  Joaquin    35   Valencia
# 2   Albert    60  Barcelona

# %%
# pasar los nombres de las columnas + skiprows
df = pd.read_csv(
    "example3.csv", 
    sep=";", 
    names=["name","age","city"],
    skiprows=1,
)

df
# Out:
#       name  age       city
# 0  Roberto   38     Madrid
# 1  Joaquin   35   Valencia
# 2   Albert   60  Barcelona

# %%
# pasar los nombres de las columnas + skiprows
df = pd.read_csv(
    "example3.csv", 
    sep=";", 
    usecols=["col2","col3"],
)

df
# Out:
#    col2       col3
# 0    38     Madrid
# 1    35   Valencia
# 2    60  Barcelona

# %%
# definir una columna como index del DF
df = pd.read_csv(
    "example4.csv", 
    sep=";",
    index_col="col4"
)

df
# Out:
#          col1  col2       col3
# col4
# A     Roberto    38     Madrid
# B     Joaquin    35   Valencia
# C      Albert    60  Barcelona

# %%
df.index
# Out:
# Index(['A', 'B', 'C'], dtype='object', name='col4')

# %% [markdown]
# ## Explorando las propriedades de un Pandas DataFrame

# %%
titanic_df = pd.read_csv("titanic.csv")
titanic_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
titanic_df.shape
# Out:
# (891, 12)

# %%
# column names
titanic_df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
"country" in titanic_df.columns
# Out:
# False

# %%
"Ticket" in titanic_df.columns
# Out:
# True

# %%
print(list(titanic_df.columns))
# Out:
# ['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked']

# %%
# Head -> .head(n) -> 5 first rows by default
titanic_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
titanic_df.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked
# 0      0  A/5 21171   7.2500   NaN        S
# 1      0   PC 17599  71.2833   C85        C

# %%
# tail(n) ->5 last rows by default 
titanic_df.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
titanic_df.tail(3)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
titanic_tail_df = titanic_df.tail(3)
print(titanic_tail_df.shape)
titanic_tail_df
# Out:
# (3, 12)
#      PassengerId  Survived  Pclass                                      Name  \
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
# data types
titanic_df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
# info()
titanic_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
# describe()
titanic_df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# ### Seleccionar columnas de un DF

# %%
titanic_df["Survived"]
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: Survived, Length: 891, dtype: int64

# %%
type(titanic_df["Survived"])
# Out:
# pandas.core.series.Series

# %%
titanic_df["Age"]
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64

# %%
titanic_df.Age
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64

# %%
# selecting multiple columnas
titanic_df[["Survived","Age","Fare"]]
# Out:
#      Survived   Age     Fare
# 0           0  22.0   7.2500
# 1           1  38.0  71.2833
# 2           1  26.0   7.9250
# 3           1  35.0  53.1000
# 4           0  35.0   8.0500
# ..        ...   ...      ...
# 886         0  27.0  13.0000
# 887         1  19.0  30.0000
# 888         0   NaN  23.4500
# 889         1  26.0  30.0000
# 890         0  32.0   7.7500
#
# [891 rows x 3 columns]

# %%
type(titanic_df[["Survived","Age"]])
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ## Subsetting a DF (loc and iloc)
#
# - loc -> label based index
# - iloc -> integer/position based index

# %%
titanic_df = pd.read_csv("titanic.csv", index_col="Name")
titanic_df
# Out:
#                                                     PassengerId  Survived  \
# Name
# Braund, Mr. Owen Harris                                       1         0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...            2         1
# Heikkinen, Miss. Laina                                        3         1
# Futrelle, Mrs. Jacques Heath (Lily May Peel)                  4         1
# Allen, Mr. William Henry                                      5         0
# ...                                                         ...       ...
# Montvila, Rev. Juozas                                       887         0
# Graham, Miss. Margaret Edith                                888         1
# Johnston, Miss. Catherine Helen "Carrie"                    889         0
# Behr, Mr. Karl Howell                                       890         1
# Dooley, Mr. Patrick                                         891         0
#
#                                                     Pclass     Sex   Age  \
# Name
# Braund, Mr. Owen Harris                                  3    male  22.0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...       1  female  38.0
# Heikkinen, Miss. Laina                                   3  female  26.0
# Futrelle, Mrs. Jacques Heath (Lily May Peel)             1  female  35.0
# Allen, Mr. William Henry                                 3    male  35.0
# ...                                                    ...     ...   ...
# Montvila, Rev. Juozas                                    2    male  27.0
# Graham, Miss. Margaret Edith                             1  female  19.0
# Johnston, Miss. Catherine Helen "Carrie"                 3  female   NaN
# Behr, Mr. Karl Howell                                    1    male  26.0
# Dooley, Mr. Patrick                                      3    male  32.0
#
#                                                     SibSp  Parch  \
# Name
# Braund, Mr. Owen Harris                                 1      0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...      1      0
# Heikkinen, Miss. Laina                                  0      0
# Futrelle, Mrs. Jacques Heath (Lily May Peel)            1      0
# Allen, Mr. William Henry                                0      0
# ...                                                   ...    ...
# Montvila, Rev. Juozas                                   0      0
# Graham, Miss. Margaret Edith                            0      0
# Johnston, Miss. Catherine Helen "Carrie"                1      2
# Behr, Mr. Karl Howell                                   0      0
# Dooley, Mr. Patrick                                     0      0
#
#                                                               Ticket     Fare  \
# Name
# Braund, Mr. Owen Harris                                    A/5 21171   7.2500
# Cumings, Mrs. John Bradley (Florence Briggs Tha...          PC 17599  71.2833
# Heikkinen, Miss. Laina                              STON/O2. 3101282   7.9250
# Futrelle, Mrs. Jacques Heath (Lily May Peel)                  113803  53.1000
# Allen, Mr. William Henry                                      373450   8.0500
# ...                                                              ...      ...
# Montvila, Rev. Juozas                                         211536  13.0000
# Graham, Miss. Margaret Edith                                  112053  30.0000
# Johnston, Miss. Catherine Helen "Carrie"                  W./C. 6607  23.4500
# Behr, Mr. Karl Howell                                         111369  30.0000
# Dooley, Mr. Patrick                                           370376   7.7500
#
#                                                    Cabin Embarked
# Name
# Braund, Mr. Owen Harris                              NaN        S
# Cumings, Mrs. John Bradley (Florence Briggs Tha...   C85        C
# Heikkinen, Miss. Laina                               NaN        S
# Futrelle, Mrs. Jacques Heath (Lily May Peel)        C123        S
# Allen, Mr. William Henry                             NaN        S
# ...                                                  ...      ...
# Montvila, Rev. Juozas                                NaN        S
# Graham, Miss. Margaret Edith                         B42        S
# Johnston, Miss. Catherine Helen "Carrie"             NaN        S
# Behr, Mr. Karl Howell                               C148        C
# Dooley, Mr. Patrick                                  NaN        Q
#
# [891 rows x 11 columns]

# %%
titanic_df.index
# Out:
# Index(['Braund, Mr. Owen Harris',
#        'Cumings, Mrs. John Bradley (Florence Briggs Thayer)',
#        'Heikkinen, Miss. Laina',
#        'Futrelle, Mrs. Jacques Heath (Lily May Peel)',
#        'Allen, Mr. William Henry', 'Moran, Mr. James',
#        'McCarthy, Mr. Timothy J', 'Palsson, Master. Gosta Leonard',
#        'Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)',
#        'Nasser, Mrs. Nicholas (Adele Achem)',
#        ...
#        'Markun, Mr. Johann', 'Dahlberg, Miss. Gerda Ulrika',
#        'Banfield, Mr. Frederick James', 'Sutehall, Mr. Henry Jr',
#        'Rice, Mrs. William (Margaret Norton)', 'Montvila, Rev. Juozas',
#        'Graham, Miss. Margaret Edith',
#        'Johnston, Miss. Catherine Helen "Carrie"', 'Behr, Mr. Karl Howell',
#        'Dooley, Mr. Patrick'],
#       dtype='object', name='Name', length=891)

# %%
titanic_df
# Out:
#                                                     PassengerId  Survived  \
# Name
# Braund, Mr. Owen Harris                                       1         0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...            2         1
# Heikkinen, Miss. Laina                                        3         1
# Futrelle, Mrs. Jacques Heath (Lily May Peel)                  4         1
# Allen, Mr. William Henry                                      5         0
# ...                                                         ...       ...
# Montvila, Rev. Juozas                                       887         0
# Graham, Miss. Margaret Edith                                888         1
# Johnston, Miss. Catherine Helen "Carrie"                    889         0
# Behr, Mr. Karl Howell                                       890         1
# Dooley, Mr. Patrick                                         891         0
#
#                                                     Pclass     Sex   Age  \
# Name
# Braund, Mr. Owen Harris                                  3    male  22.0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...       1  female  38.0
# Heikkinen, Miss. Laina                                   3  female  26.0
# Futrelle, Mrs. Jacques Heath (Lily May Peel)             1  female  35.0
# Allen, Mr. William Henry                                 3    male  35.0
# ...                                                    ...     ...   ...
# Montvila, Rev. Juozas                                    2    male  27.0
# Graham, Miss. Margaret Edith                             1  female  19.0
# Johnston, Miss. Catherine Helen "Carrie"                 3  female   NaN
# Behr, Mr. Karl Howell                                    1    male  26.0
# Dooley, Mr. Patrick                                      3    male  32.0
#
#                                                     SibSp  Parch  \
# Name
# Braund, Mr. Owen Harris                                 1      0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...      1      0
# Heikkinen, Miss. Laina                                  0      0
# Futrelle, Mrs. Jacques Heath (Lily May Peel)            1      0
# Allen, Mr. William Henry                                0      0
# ...                                                   ...    ...
# Montvila, Rev. Juozas                                   0      0
# Graham, Miss. Margaret Edith                            0      0
# Johnston, Miss. Catherine Helen "Carrie"                1      2
# Behr, Mr. Karl Howell                                   0      0
# Dooley, Mr. Patrick                                     0      0
#
#                                                               Ticket     Fare  \
# Name
# Braund, Mr. Owen Harris                                    A/5 21171   7.2500
# Cumings, Mrs. John Bradley (Florence Briggs Tha...          PC 17599  71.2833
# Heikkinen, Miss. Laina                              STON/O2. 3101282   7.9250
# Futrelle, Mrs. Jacques Heath (Lily May Peel)                  113803  53.1000
# Allen, Mr. William Henry                                      373450   8.0500
# ...                                                              ...      ...
# Montvila, Rev. Juozas                                         211536  13.0000
# Graham, Miss. Margaret Edith                                  112053  30.0000
# Johnston, Miss. Catherine Helen "Carrie"                  W./C. 6607  23.4500
# Behr, Mr. Karl Howell                                         111369  30.0000
# Dooley, Mr. Patrick                                           370376   7.7500
#
#                                                    Cabin Embarked
# Name
# Braund, Mr. Owen Harris                              NaN        S
# Cumings, Mrs. John Bradley (Florence Briggs Tha...   C85        C
# Heikkinen, Miss. Laina                               NaN        S
# Futrelle, Mrs. Jacques Heath (Lily May Peel)        C123        S
# Allen, Mr. William Henry                             NaN        S
# ...                                                  ...      ...
# Montvila, Rev. Juozas                                NaN        S
# Graham, Miss. Margaret Edith                         B42        S
# Johnston, Miss. Catherine Helen "Carrie"             NaN        S
# Behr, Mr. Karl Howell                               C148        C
# Dooley, Mr. Patrick                                  NaN        Q
#
# [891 rows x 11 columns]

# %%
# .loc[] -> label index 
titanic_df.loc['Heikkinen, Miss. Laina']
# Out:
# PassengerId                   3
# Survived                      1
# Pclass                        3
# Sex                      female
# Age                        26.0
# SibSp                         0
# Parch                         0
# Ticket         STON/O2. 3101282
# Fare                      7.925
# Cabin                       NaN
# Embarked                      S
# Name: Heikkinen, Miss. Laina, dtype: object

# %%
first_row = titanic_df.loc["Braund, Mr. Owen Harris"]
first_row
# Out:
# PassengerId            1
# Survived               0
# Pclass                 3
# Sex                 male
# Age                 22.0
# SibSp                  1
# Parch                  0
# Ticket         A/5 21171
# Fare                7.25
# Cabin                NaN
# Embarked               S
# Name: Braund, Mr. Owen Harris, dtype: object

# %%
first_row["Age"]
# Out:
# 22.0

# %%
titanic_df.iloc[0]
# Out:
# PassengerId            1
# Survived               0
# Pclass                 3
# Sex                 male
# Age                 22.0
# SibSp                  1
# Parch                  0
# Ticket         A/5 21171
# Fare                7.25
# Cabin                NaN
# Embarked               S
# Name: Braund, Mr. Owen Harris, dtype: object

# %%
titanic_df.iloc[-1]
# Out:
# PassengerId       891
# Survived            0
# Pclass              3
# Sex              male
# Age              32.0
# SibSp               0
# Parch               0
# Ticket         370376
# Fare             7.75
# Cabin             NaN
# Embarked            Q
# Name: Dooley, Mr. Patrick, dtype: object

# %%
titanic_df.tail(1)
# Out:
#                      PassengerId  Survived  Pclass   Sex   Age  SibSp  Parch  \
# Name
# Dooley, Mr. Patrick          891         0       3  male  32.0      0      0
#
#                      Ticket  Fare Cabin Embarked
# Name
# Dooley, Mr. Patrick  370376  7.75   NaN        Q

# %%
selected_names = [
    "Dooley, Mr. Patrick",
    "Braund, Mr. Owen Harris",
]

sample_df = titanic_df.loc[selected_names]
sample_df
# Out:
#                          PassengerId  Survived  Pclass   Sex   Age  SibSp  \
# Name
# Dooley, Mr. Patrick              891         0       3  male  32.0      0
# Braund, Mr. Owen Harris            1         0       3  male  22.0      1
#
#                          Parch     Ticket  Fare Cabin Embarked
# Name
# Dooley, Mr. Patrick          0     370376  7.75   NaN        Q
# Braund, Mr. Owen Harris      0  A/5 21171  7.25   NaN        S

# %%
selected_names = [
    "Dooley, Mr. Patrick",
    "Braund, Mr. Owen Harris",
]

titanic_df.loc[selected_names , ["PassengerId","Survived","Age"]]
# Out:
#                          PassengerId  Survived   Age
# Name
# Dooley, Mr. Patrick              891         0  32.0
# Braund, Mr. Owen Harris            1         0  22.0

# %%
titanic_df.iloc[:3,-3:]
# Out:
#                                                        Fare Cabin Embarked
# Name
# Braund, Mr. Owen Harris                              7.2500   NaN        S
# Cumings, Mrs. John Bradley (Florence Briggs Tha...  71.2833   C85        C
# Heikkinen, Miss. Laina                               7.9250   NaN        S

# %%
# rename columns
titanic_df
# Out:
#                                                     PassengerId  Survived  \
# Name
# Braund, Mr. Owen Harris                                       1         0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...            2         1
# Heikkinen, Miss. Laina                                        3         1
# Futrelle, Mrs. Jacques Heath (Lily May Peel)                  4         1
# Allen, Mr. William Henry                                      5         0
# ...                                                         ...       ...
# Montvila, Rev. Juozas                                       887         0
# Graham, Miss. Margaret Edith                                888         1
# Johnston, Miss. Catherine Helen "Carrie"                    889         0
# Behr, Mr. Karl Howell                                       890         1
# Dooley, Mr. Patrick                                         891         0
#
#                                                     Pclass     Sex   Age  \
# Name
# Braund, Mr. Owen Harris                                  3    male  22.0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...       1  female  38.0
# Heikkinen, Miss. Laina                                   3  female  26.0
# Futrelle, Mrs. Jacques Heath (Lily May Peel)             1  female  35.0
# Allen, Mr. William Henry                                 3    male  35.0
# ...                                                    ...     ...   ...
# Montvila, Rev. Juozas                                    2    male  27.0
# Graham, Miss. Margaret Edith                             1  female  19.0
# Johnston, Miss. Catherine Helen "Carrie"                 3  female   NaN
# Behr, Mr. Karl Howell                                    1    male  26.0
# Dooley, Mr. Patrick                                      3    male  32.0
#
#                                                     SibSp  Parch  \
# Name
# Braund, Mr. Owen Harris                                 1      0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...      1      0
# Heikkinen, Miss. Laina                                  0      0
# Futrelle, Mrs. Jacques Heath (Lily May Peel)            1      0
# Allen, Mr. William Henry                                0      0
# ...                                                   ...    ...
# Montvila, Rev. Juozas                                   0      0
# Graham, Miss. Margaret Edith                            0      0
# Johnston, Miss. Catherine Helen "Carrie"                1      2
# Behr, Mr. Karl Howell                                   0      0
# Dooley, Mr. Patrick                                     0      0
#
#                                                               Ticket     Fare  \
# Name
# Braund, Mr. Owen Harris                                    A/5 21171   7.2500
# Cumings, Mrs. John Bradley (Florence Briggs Tha...          PC 17599  71.2833
# Heikkinen, Miss. Laina                              STON/O2. 3101282   7.9250
# Futrelle, Mrs. Jacques Heath (Lily May Peel)                  113803  53.1000
# Allen, Mr. William Henry                                      373450   8.0500
# ...                                                              ...      ...
# Montvila, Rev. Juozas                                         211536  13.0000
# Graham, Miss. Margaret Edith                                  112053  30.0000
# Johnston, Miss. Catherine Helen "Carrie"                  W./C. 6607  23.4500
# Behr, Mr. Karl Howell                                         111369  30.0000
# Dooley, Mr. Patrick                                           370376   7.7500
#
#                                                    Cabin Embarked
# Name
# Braund, Mr. Owen Harris                              NaN        S
# Cumings, Mrs. John Bradley (Florence Briggs Tha...   C85        C
# Heikkinen, Miss. Laina                               NaN        S
# Futrelle, Mrs. Jacques Heath (Lily May Peel)        C123        S
# Allen, Mr. William Henry                             NaN        S
# ...                                                  ...      ...
# Montvila, Rev. Juozas                                NaN        S
# Graham, Miss. Margaret Edith                         B42        S
# Johnston, Miss. Catherine Helen "Carrie"             NaN        S
# Behr, Mr. Karl Howell                               C148        C
# Dooley, Mr. Patrick                                  NaN        Q
#
# [891 rows x 11 columns]

# %%
titanic_df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Sex', 'Age', 'SibSp', 'Parch',
#        'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
new_columns = []
for col in titanic_df.columns:
    new_columns.append(str(col).strip().lower())
new_columns
# Out:
# ['passengerid',
#  'survived',
#  'pclass',
#  'sex',
#  'age',
#  'sibsp',
#  'parch',
#  'ticket',
#  'fare',
#  'cabin',
#  'embarked']

# %%
titanic_df.columns = new_columns
titanic_df
# Out:
#                                                     passengerid  survived  \
# Name
# Braund, Mr. Owen Harris                                       1         0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...            2         1
# Heikkinen, Miss. Laina                                        3         1
# Futrelle, Mrs. Jacques Heath (Lily May Peel)                  4         1
# Allen, Mr. William Henry                                      5         0
# ...                                                         ...       ...
# Montvila, Rev. Juozas                                       887         0
# Graham, Miss. Margaret Edith                                888         1
# Johnston, Miss. Catherine Helen "Carrie"                    889         0
# Behr, Mr. Karl Howell                                       890         1
# Dooley, Mr. Patrick                                         891         0
#
#                                                     pclass     sex   age  \
# Name
# Braund, Mr. Owen Harris                                  3    male  22.0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...       1  female  38.0
# Heikkinen, Miss. Laina                                   3  female  26.0
# Futrelle, Mrs. Jacques Heath (Lily May Peel)             1  female  35.0
# Allen, Mr. William Henry                                 3    male  35.0
# ...                                                    ...     ...   ...
# Montvila, Rev. Juozas                                    2    male  27.0
# Graham, Miss. Margaret Edith                             1  female  19.0
# Johnston, Miss. Catherine Helen "Carrie"                 3  female   NaN
# Behr, Mr. Karl Howell                                    1    male  26.0
# Dooley, Mr. Patrick                                      3    male  32.0
#
#                                                     sibsp  parch  \
# Name
# Braund, Mr. Owen Harris                                 1      0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...      1      0
# Heikkinen, Miss. Laina                                  0      0
# Futrelle, Mrs. Jacques Heath (Lily May Peel)            1      0
# Allen, Mr. William Henry                                0      0
# ...                                                   ...    ...
# Montvila, Rev. Juozas                                   0      0
# Graham, Miss. Margaret Edith                            0      0
# Johnston, Miss. Catherine Helen "Carrie"                1      2
# Behr, Mr. Karl Howell                                   0      0
# Dooley, Mr. Patrick                                     0      0
#
#                                                               ticket     fare  \
# Name
# Braund, Mr. Owen Harris                                    A/5 21171   7.2500
# Cumings, Mrs. John Bradley (Florence Briggs Tha...          PC 17599  71.2833
# Heikkinen, Miss. Laina                              STON/O2. 3101282   7.9250
# Futrelle, Mrs. Jacques Heath (Lily May Peel)                  113803  53.1000
# Allen, Mr. William Henry                                      373450   8.0500
# ...                                                              ...      ...
# Montvila, Rev. Juozas                                         211536  13.0000
# Graham, Miss. Margaret Edith                                  112053  30.0000
# Johnston, Miss. Catherine Helen "Carrie"                  W./C. 6607  23.4500
# Behr, Mr. Karl Howell                                         111369  30.0000
# Dooley, Mr. Patrick                                           370376   7.7500
#
#                                                    cabin embarked
# Name
# Braund, Mr. Owen Harris                              NaN        S
# Cumings, Mrs. John Bradley (Florence Briggs Tha...   C85        C
# Heikkinen, Miss. Laina                               NaN        S
# Futrelle, Mrs. Jacques Heath (Lily May Peel)        C123        S
# Allen, Mr. William Henry                             NaN        S
# ...                                                  ...      ...
# Montvila, Rev. Juozas                                NaN        S
# Graham, Miss. Margaret Edith                         B42        S
# Johnston, Miss. Catherine Helen "Carrie"             NaN        S
# Behr, Mr. Karl Howell                               C148        C
# Dooley, Mr. Patrick                                  NaN        Q
#
# [891 rows x 11 columns]

# %% [markdown]
# ## Filtering rows on conditions
#
# * filter
# * mask + loc
# * where
# * query

# %%
sample_df = titanic_df.sample(5)
sample_df
# Out:
#                                                 passengerid  survived  pclass  \
# Name
# Smart, Mr. John Montgomery                              468         0       1
# Sjoblom, Miss. Anna Sofia                               787         1       3
# Horgan, Mr. John                                        614         0       3
# Rothschild, Mrs. Martin (Elizabeth L. Barrett)          514         1       1
# Mellinger, Miss. Madeleine Violet                       447         1       2
#
#                                                    sex   age  sibsp  parch  \
# Name
# Smart, Mr. John Montgomery                        male  56.0      0      0
# Sjoblom, Miss. Anna Sofia                       female  18.0      0      0
# Horgan, Mr. John                                  male   NaN      0      0
# Rothschild, Mrs. Martin (Elizabeth L. Barrett)  female  54.0      1      0
# Mellinger, Miss. Madeleine Violet               female  13.0      0      1
#
#                                                   ticket     fare cabin  \
# Name
# Smart, Mr. John Montgomery                        113792  26.5500   NaN
# Sjoblom, Miss. Anna Sofia                        3101265   7.4958   NaN
# Horgan, Mr. John                                  370377   7.7500   NaN
# Rothschild, Mrs. Martin (Elizabeth L. Barrett)  PC 17603  59.4000   NaN
# Mellinger, Miss. Madeleine Violet                 250644  19.5000   NaN
#
#                                                embarked
# Name
# Smart, Mr. John Montgomery                            S
# Sjoblom, Miss. Anna Sofia                             S
# Horgan, Mr. John                                      Q
# Rothschild, Mrs. Martin (Elizabeth L. Barrett)        C
# Mellinger, Miss. Madeleine Violet                     S

# %%
sample_df["sex"] == "female"
# Out:
# Name
# Smart, Mr. John Montgomery                        False
# Sjoblom, Miss. Anna Sofia                          True
# Horgan, Mr. John                                  False
# Rothschild, Mrs. Martin (Elizabeth L. Barrett)     True
# Mellinger, Miss. Madeleine Violet                  True
# Name: sex, dtype: bool

# %%
filter_sex = sample_df["sex"] == "female"
sample_df[filter_sex]
# Out:
#                                                 passengerid  survived  pclass  \
# Name
# Sjoblom, Miss. Anna Sofia                               787         1       3
# Rothschild, Mrs. Martin (Elizabeth L. Barrett)          514         1       1
# Mellinger, Miss. Madeleine Violet                       447         1       2
#
#                                                    sex   age  sibsp  parch  \
# Name
# Sjoblom, Miss. Anna Sofia                       female  18.0      0      0
# Rothschild, Mrs. Martin (Elizabeth L. Barrett)  female  54.0      1      0
# Mellinger, Miss. Madeleine Violet               female  13.0      0      1
#
#                                                   ticket     fare cabin  \
# Name
# Sjoblom, Miss. Anna Sofia                        3101265   7.4958   NaN
# Rothschild, Mrs. Martin (Elizabeth L. Barrett)  PC 17603  59.4000   NaN
# Mellinger, Miss. Madeleine Violet                 250644  19.5000   NaN
#
#                                                embarked
# Name
# Sjoblom, Miss. Anna Sofia                             S
# Rothschild, Mrs. Martin (Elizabeth L. Barrett)        C
# Mellinger, Miss. Madeleine Violet                     S

# %%
sample_df[sample_df["sex"] == "female"]
# Out:
#                                                 passengerid  survived  pclass  \
# Name
# Sjoblom, Miss. Anna Sofia                               787         1       3
# Rothschild, Mrs. Martin (Elizabeth L. Barrett)          514         1       1
# Mellinger, Miss. Madeleine Violet                       447         1       2
#
#                                                    sex   age  sibsp  parch  \
# Name
# Sjoblom, Miss. Anna Sofia                       female  18.0      0      0
# Rothschild, Mrs. Martin (Elizabeth L. Barrett)  female  54.0      1      0
# Mellinger, Miss. Madeleine Violet               female  13.0      0      1
#
#                                                   ticket     fare cabin  \
# Name
# Sjoblom, Miss. Anna Sofia                        3101265   7.4958   NaN
# Rothschild, Mrs. Martin (Elizabeth L. Barrett)  PC 17603  59.4000   NaN
# Mellinger, Miss. Madeleine Violet                 250644  19.5000   NaN
#
#                                                embarked
# Name
# Sjoblom, Miss. Anna Sofia                             S
# Rothschild, Mrs. Martin (Elizabeth L. Barrett)        C
# Mellinger, Miss. Madeleine Violet                     S

# %%
# not female -> ~
sample_df[~(sample_df["sex"] == "female")]
# Out:
#                             passengerid  survived  pclass   sex   age  sibsp  \
# Name
# Smart, Mr. John Montgomery          468         0       1  male  56.0      0
# Horgan, Mr. John                    614         0       3  male   NaN      0
#
#                             parch  ticket   fare cabin embarked
# Name
# Smart, Mr. John Montgomery      0  113792  26.55   NaN        S
# Horgan, Mr. John                0  370377   7.75   NaN        Q

# %%
# best practices -> .loc[filter]
filter_sex = sample_df["sex"] == "female"
sample_df.loc[filter_sex,:]
# Out:
#                                                 passengerid  survived  pclass  \
# Name
# Sjoblom, Miss. Anna Sofia                               787         1       3
# Rothschild, Mrs. Martin (Elizabeth L. Barrett)          514         1       1
# Mellinger, Miss. Madeleine Violet                       447         1       2
#
#                                                    sex   age  sibsp  parch  \
# Name
# Sjoblom, Miss. Anna Sofia                       female  18.0      0      0
# Rothschild, Mrs. Martin (Elizabeth L. Barrett)  female  54.0      1      0
# Mellinger, Miss. Madeleine Violet               female  13.0      0      1
#
#                                                   ticket     fare cabin  \
# Name
# Sjoblom, Miss. Anna Sofia                        3101265   7.4958   NaN
# Rothschild, Mrs. Martin (Elizabeth L. Barrett)  PC 17603  59.4000   NaN
# Mellinger, Miss. Madeleine Violet                 250644  19.5000   NaN
#
#                                                embarked
# Name
# Sjoblom, Miss. Anna Sofia                             S
# Rothschild, Mrs. Martin (Elizabeth L. Barrett)        C
# Mellinger, Miss. Madeleine Violet                     S

# %%
sample_df.loc[filter_sex,["survived","ticket"]]
# Out:
#                                                 survived    ticket
# Name
# Sjoblom, Miss. Anna Sofia                              1   3101265
# Rothschild, Mrs. Martin (Elizabeth L. Barrett)         1  PC 17603
# Mellinger, Miss. Madeleine Violet                      1    250644

# %%
# query
sample_df.query("sex == 'female'")
# Out:
#                                                 passengerid  survived  pclass  \
# Name
# Sjoblom, Miss. Anna Sofia                               787         1       3
# Rothschild, Mrs. Martin (Elizabeth L. Barrett)          514         1       1
# Mellinger, Miss. Madeleine Violet                       447         1       2
#
#                                                    sex   age  sibsp  parch  \
# Name
# Sjoblom, Miss. Anna Sofia                       female  18.0      0      0
# Rothschild, Mrs. Martin (Elizabeth L. Barrett)  female  54.0      1      0
# Mellinger, Miss. Madeleine Violet               female  13.0      0      1
#
#                                                   ticket     fare cabin  \
# Name
# Sjoblom, Miss. Anna Sofia                        3101265   7.4958   NaN
# Rothschild, Mrs. Martin (Elizabeth L. Barrett)  PC 17603  59.4000   NaN
# Mellinger, Miss. Madeleine Violet                 250644  19.5000   NaN
#
#                                                embarked
# Name
# Sjoblom, Miss. Anna Sofia                             S
# Rothschild, Mrs. Martin (Elizabeth L. Barrett)        C
# Mellinger, Miss. Madeleine Violet                     S

# %%
# multiple filters: & (and) y | (or)
filter_sex = sample_df["sex"] == "female"
filter_age = sample_df["age"] <= 20

sample_df[(filter_sex)&(filter_age)]
# Out:
#                                    passengerid  survived  pclass     sex  \
# Name
# Sjoblom, Miss. Anna Sofia                  787         1       3  female
# Mellinger, Miss. Madeleine Violet          447         1       2  female
#
#                                     age  sibsp  parch   ticket     fare cabin  \
# Name
# Sjoblom, Miss. Anna Sofia          18.0      0      0  3101265   7.4958   NaN
# Mellinger, Miss. Madeleine Violet  13.0      0      1   250644  19.5000   NaN
#
#                                   embarked
# Name
# Sjoblom, Miss. Anna Sofia                S
# Mellinger, Miss. Madeleine Violet        S

# %%
# or
sample_df[(filter_sex)|(filter_age)]
# Out:
#                                                 passengerid  survived  pclass  \
# Name
# Sjoblom, Miss. Anna Sofia                               787         1       3
# Rothschild, Mrs. Martin (Elizabeth L. Barrett)          514         1       1
# Mellinger, Miss. Madeleine Violet                       447         1       2
#
#                                                    sex   age  sibsp  parch  \
# Name
# Sjoblom, Miss. Anna Sofia                       female  18.0      0      0
# Rothschild, Mrs. Martin (Elizabeth L. Barrett)  female  54.0      1      0
# Mellinger, Miss. Madeleine Violet               female  13.0      0      1
#
#                                                   ticket     fare cabin  \
# Name
# Sjoblom, Miss. Anna Sofia                        3101265   7.4958   NaN
# Rothschild, Mrs. Martin (Elizabeth L. Barrett)  PC 17603  59.4000   NaN
# Mellinger, Miss. Madeleine Violet                 250644  19.5000   NaN
#
#                                                embarked
# Name
# Sjoblom, Miss. Anna Sofia                             S
# Rothschild, Mrs. Martin (Elizabeth L. Barrett)        C
# Mellinger, Miss. Madeleine Violet                     S

# %%
# error: and/or
sample_df[(filter_sex)or(filter_age)]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [92], line 1
# ----> 1 sample_df[(filter_sex)or(filter_age)]
#
# File ~/git_repos/personal/formacion_python/sesion_6/venv_sesion6/lib/python3.8/site-packages/pandas/core/generic.py:1526, in NDFrame.__nonzero__(self)
#    1524 @final
#    1525 def __nonzero__(self) -> NoReturn:
# -> 1526     raise ValueError(
#    1527         f"The truth value of a {type(self).__name__} is ambiguous. "
#    1528         "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1529     )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %% [markdown]
# ## sort_values(), duplicados(), null values

# %%
# sort DF
sample_df
# Out:
#                                                 passengerid  survived  pclass  \
# Name
# Smart, Mr. John Montgomery                              468         0       1
# Sjoblom, Miss. Anna Sofia                               787         1       3
# Horgan, Mr. John                                        614         0       3
# Rothschild, Mrs. Martin (Elizabeth L. Barrett)          514         1       1
# Mellinger, Miss. Madeleine Violet                       447         1       2
#
#                                                    sex   age  sibsp  parch  \
# Name
# Smart, Mr. John Montgomery                        male  56.0      0      0
# Sjoblom, Miss. Anna Sofia                       female  18.0      0      0
# Horgan, Mr. John                                  male   NaN      0      0
# Rothschild, Mrs. Martin (Elizabeth L. Barrett)  female  54.0      1      0
# Mellinger, Miss. Madeleine Violet               female  13.0      0      1
#
#                                                   ticket     fare cabin  \
# Name
# Smart, Mr. John Montgomery                        113792  26.5500   NaN
# Sjoblom, Miss. Anna Sofia                        3101265   7.4958   NaN
# Horgan, Mr. John                                  370377   7.7500   NaN
# Rothschild, Mrs. Martin (Elizabeth L. Barrett)  PC 17603  59.4000   NaN
# Mellinger, Miss. Madeleine Violet                 250644  19.5000   NaN
#
#                                                embarked
# Name
# Smart, Mr. John Montgomery                            S
# Sjoblom, Miss. Anna Sofia                             S
# Horgan, Mr. John                                      Q
# Rothschild, Mrs. Martin (Elizabeth L. Barrett)        C
# Mellinger, Miss. Madeleine Violet                     S

# %%
# sort by index
sample_df.sort_index()
# Out:
#                                                 passengerid  survived  pclass  \
# Name
# Horgan, Mr. John                                        614         0       3
# Mellinger, Miss. Madeleine Violet                       447         1       2
# Rothschild, Mrs. Martin (Elizabeth L. Barrett)          514         1       1
# Sjoblom, Miss. Anna Sofia                               787         1       3
# Smart, Mr. John Montgomery                              468         0       1
#
#                                                    sex   age  sibsp  parch  \
# Name
# Horgan, Mr. John                                  male   NaN      0      0
# Mellinger, Miss. Madeleine Violet               female  13.0      0      1
# Rothschild, Mrs. Martin (Elizabeth L. Barrett)  female  54.0      1      0
# Sjoblom, Miss. Anna Sofia                       female  18.0      0      0
# Smart, Mr. John Montgomery                        male  56.0      0      0
#
#                                                   ticket     fare cabin  \
# Name
# Horgan, Mr. John                                  370377   7.7500   NaN
# Mellinger, Miss. Madeleine Violet                 250644  19.5000   NaN
# Rothschild, Mrs. Martin (Elizabeth L. Barrett)  PC 17603  59.4000   NaN
# Sjoblom, Miss. Anna Sofia                        3101265   7.4958   NaN
# Smart, Mr. John Montgomery                        113792  26.5500   NaN
#
#                                                embarked
# Name
# Horgan, Mr. John                                      Q
# Mellinger, Miss. Madeleine Violet                     S
# Rothschild, Mrs. Martin (Elizabeth L. Barrett)        C
# Sjoblom, Miss. Anna Sofia                             S
# Smart, Mr. John Montgomery                            S

# %%
# sort by index
sample_df.sort_index(ascending=False)
# Out:
#                                                 passengerid  survived  pclass  \
# Name
# Smart, Mr. John Montgomery                              468         0       1
# Sjoblom, Miss. Anna Sofia                               787         1       3
# Rothschild, Mrs. Martin (Elizabeth L. Barrett)          514         1       1
# Mellinger, Miss. Madeleine Violet                       447         1       2
# Horgan, Mr. John                                        614         0       3
#
#                                                    sex   age  sibsp  parch  \
# Name
# Smart, Mr. John Montgomery                        male  56.0      0      0
# Sjoblom, Miss. Anna Sofia                       female  18.0      0      0
# Rothschild, Mrs. Martin (Elizabeth L. Barrett)  female  54.0      1      0
# Mellinger, Miss. Madeleine Violet               female  13.0      0      1
# Horgan, Mr. John                                  male   NaN      0      0
#
#                                                   ticket     fare cabin  \
# Name
# Smart, Mr. John Montgomery                        113792  26.5500   NaN
# Sjoblom, Miss. Anna Sofia                        3101265   7.4958   NaN
# Rothschild, Mrs. Martin (Elizabeth L. Barrett)  PC 17603  59.4000   NaN
# Mellinger, Miss. Madeleine Violet                 250644  19.5000   NaN
# Horgan, Mr. John                                  370377   7.7500   NaN
#
#                                                embarked
# Name
# Smart, Mr. John Montgomery                            S
# Sjoblom, Miss. Anna Sofia                             S
# Rothschild, Mrs. Martin (Elizabeth L. Barrett)        C
# Mellinger, Miss. Madeleine Violet                     S
# Horgan, Mr. John                                      Q

# %%
sample_df.sort_values("fare",ascending=False)
# Out:
#                                                 passengerid  survived  pclass  \
# Name
# Rothschild, Mrs. Martin (Elizabeth L. Barrett)          514         1       1
# Smart, Mr. John Montgomery                              468         0       1
# Mellinger, Miss. Madeleine Violet                       447         1       2
# Horgan, Mr. John                                        614         0       3
# Sjoblom, Miss. Anna Sofia                               787         1       3
#
#                                                    sex   age  sibsp  parch  \
# Name
# Rothschild, Mrs. Martin (Elizabeth L. Barrett)  female  54.0      1      0
# Smart, Mr. John Montgomery                        male  56.0      0      0
# Mellinger, Miss. Madeleine Violet               female  13.0      0      1
# Horgan, Mr. John                                  male   NaN      0      0
# Sjoblom, Miss. Anna Sofia                       female  18.0      0      0
#
#                                                   ticket     fare cabin  \
# Name
# Rothschild, Mrs. Martin (Elizabeth L. Barrett)  PC 17603  59.4000   NaN
# Smart, Mr. John Montgomery                        113792  26.5500   NaN
# Mellinger, Miss. Madeleine Violet                 250644  19.5000   NaN
# Horgan, Mr. John                                  370377   7.7500   NaN
# Sjoblom, Miss. Anna Sofia                        3101265   7.4958   NaN
#
#                                                embarked
# Name
# Rothschild, Mrs. Martin (Elizabeth L. Barrett)        C
# Smart, Mr. John Montgomery                            S
# Mellinger, Miss. Madeleine Violet                     S
# Horgan, Mr. John                                      Q
# Sjoblom, Miss. Anna Sofia                             S

# %%
sample_df.sort_values(["pclass","fare"],ascending=[True,False])
# Out:
#                                                 passengerid  survived  pclass  \
# Name
# Rothschild, Mrs. Martin (Elizabeth L. Barrett)          514         1       1
# Smart, Mr. John Montgomery                              468         0       1
# Mellinger, Miss. Madeleine Violet                       447         1       2
# Horgan, Mr. John                                        614         0       3
# Sjoblom, Miss. Anna Sofia                               787         1       3
#
#                                                    sex   age  sibsp  parch  \
# Name
# Rothschild, Mrs. Martin (Elizabeth L. Barrett)  female  54.0      1      0
# Smart, Mr. John Montgomery                        male  56.0      0      0
# Mellinger, Miss. Madeleine Violet               female  13.0      0      1
# Horgan, Mr. John                                  male   NaN      0      0
# Sjoblom, Miss. Anna Sofia                       female  18.0      0      0
#
#                                                   ticket     fare cabin  \
# Name
# Rothschild, Mrs. Martin (Elizabeth L. Barrett)  PC 17603  59.4000   NaN
# Smart, Mr. John Montgomery                        113792  26.5500   NaN
# Mellinger, Miss. Madeleine Violet                 250644  19.5000   NaN
# Horgan, Mr. John                                  370377   7.7500   NaN
# Sjoblom, Miss. Anna Sofia                        3101265   7.4958   NaN
#
#                                                embarked
# Name
# Rothschild, Mrs. Martin (Elizabeth L. Barrett)        C
# Smart, Mr. John Montgomery                            S
# Mellinger, Miss. Madeleine Violet                     S
# Horgan, Mr. John                                      Q
# Sjoblom, Miss. Anna Sofia                             S

# %% [markdown]
# **duplicates**

# %%
sample_df.drop_duplicates()
# Out:
#                                                 passengerid  survived  pclass  \
# Name
# Smart, Mr. John Montgomery                              468         0       1
# Sjoblom, Miss. Anna Sofia                               787         1       3
# Horgan, Mr. John                                        614         0       3
# Rothschild, Mrs. Martin (Elizabeth L. Barrett)          514         1       1
# Mellinger, Miss. Madeleine Violet                       447         1       2
#
#                                                    sex   age  sibsp  parch  \
# Name
# Smart, Mr. John Montgomery                        male  56.0      0      0
# Sjoblom, Miss. Anna Sofia                       female  18.0      0      0
# Horgan, Mr. John                                  male   NaN      0      0
# Rothschild, Mrs. Martin (Elizabeth L. Barrett)  female  54.0      1      0
# Mellinger, Miss. Madeleine Violet               female  13.0      0      1
#
#                                                   ticket     fare cabin  \
# Name
# Smart, Mr. John Montgomery                        113792  26.5500   NaN
# Sjoblom, Miss. Anna Sofia                        3101265   7.4958   NaN
# Horgan, Mr. John                                  370377   7.7500   NaN
# Rothschild, Mrs. Martin (Elizabeth L. Barrett)  PC 17603  59.4000   NaN
# Mellinger, Miss. Madeleine Violet                 250644  19.5000   NaN
#
#                                                embarked
# Name
# Smart, Mr. John Montgomery                            S
# Sjoblom, Miss. Anna Sofia                             S
# Horgan, Mr. John                                      Q
# Rothschild, Mrs. Martin (Elizabeth L. Barrett)        C
# Mellinger, Miss. Madeleine Violet                     S

# %%
df = pd.DataFrame({
    "name":["Roberto","Roberto","Joaquin"],
    "age":[38,38,38]
})

df
# Out:
#       name  age
# 0  Roberto   38
# 1  Roberto   38
# 2  Joaquin   38

# %%
df.drop_duplicates()
# Out:
#       name  age
# 0  Roberto   38
# 2  Joaquin   38

# %%
df.drop_duplicates(keep='last')
# Out:
#       name  age
# 1  Roberto   38
# 2  Joaquin   38

# %%
df.drop_duplicates(subset=["age"],keep="last")
# Out:
#       name  age
# 2  Joaquin   38

# %% [markdown]
# **null values**

# %%
titanic_df = pd.read_csv("titanic.csv")
titanic_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
titanic_df.isnull()
# Out:
#      PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0          False     False   False  False  False  False  False  False   False
# 1          False     False   False  False  False  False  False  False   False
# 2          False     False   False  False  False  False  False  False   False
# 3          False     False   False  False  False  False  False  False   False
# 4          False     False   False  False  False  False  False  False   False
# ..           ...       ...     ...    ...    ...    ...    ...    ...     ...
# 886        False     False   False  False  False  False  False  False   False
# 887        False     False   False  False  False  False  False  False   False
# 888        False     False   False  False  False   True  False  False   False
# 889        False     False   False  False  False  False  False  False   False
# 890        False     False   False  False  False  False  False  False   False
#
#       Fare  Cabin  Embarked
# 0    False   True     False
# 1    False  False     False
# 2    False   True     False
# 3    False  False     False
# 4    False   True     False
# ..     ...    ...       ...
# 886  False   True     False
# 887  False  False     False
# 888  False   True     False
# 889  False  False     False
# 890  False   True     False
#
# [891 rows x 12 columns]

# %%
titanic_df["Cabin"].isnull()
# Out:
# 0       True
# 1      False
# 2       True
# 3      False
# 4       True
#        ...
# 886     True
# 887    False
# 888     True
# 889    False
# 890     True
# Name: Cabin, Length: 891, dtype: bool

# %%
titanic_df["Cabin"].isnull().sum()
# Out:
# 687

# %%
titanic_df["Cabin"].isnull().mean()
# Out:
# 0.7710437710437711

# %%
titanic_df.isnull().mean()
# Out:
# PassengerId    0.000000
# Survived       0.000000
# Pclass         0.000000
# Name           0.000000
# Sex            0.000000
# Age            0.198653
# SibSp          0.000000
# Parch          0.000000
# Ticket         0.000000
# Fare           0.000000
# Cabin          0.771044
# Embarked       0.002245
# dtype: float64

# %%
titanic_df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64
