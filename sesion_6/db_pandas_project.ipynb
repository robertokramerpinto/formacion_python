# %% [markdown]
# # Project - Data Analysis
#
# - Crear un DB para titanic
# - Read from sql into Pandas DF
# - Exploratory Data Analysis

# %%
import sqlite3
import pandas as pd
import matplotlib.pyplot as plt

# %%
#!pip install matplotlib

# %%
# creating connection to DB 
db_name = "titanic_project.db"
conn = sqlite3.connect(db_name)

# %%
# Lecturda de un csv -> pandas DF
raw_df = pd.read_csv("titanic.csv")
raw_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# ### write .to_csv()

# %%
head_df = raw_df.head(10)
head_df
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
head_df.to_csv("head_titanic.csv",index=False)

# %% [markdown]
# ### write .to_sql()

# %%
raw_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# QUERY VALUES FROM DB
db_name = "titanic_project.db"
conn = sqlite3.connect(db_name)
cursor = conn.cursor()
raw_df.to_sql("titanic",con=conn,index=False,if_exists="replace")
# Out:
# 891

# %%
# QUERY VALUES FROM DB
db_name = "titanic_project.db"
conn = sqlite3.connect(db_name)
cursor = conn.cursor()

sql_str = """SELECT * FROM titanic"""

cursor.execute(sql_str)
result = cursor.fetchall()

conn.commit()
conn.close()

len(result)
# Out:
# 891

# %%
# QUERY VALUES FROM DB
db_name = "titanic_project.db"
conn = sqlite3.connect(db_name)
cursor = conn.cursor()

titanic_df = pd.read_sql("SELECT * FROM titanic", con=conn)
conn.close()

titanic_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# ## Data Analysis

# %%
titanic_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500  None        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250  None        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500  None        S

# %% [markdown]
# * Cual es el % de Survived?

# %%
titanic_df["Survived"].mean()
# Out:
# 0.3838383838383838

# %%
titanic_df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
titanic_df["Survived"].std()
# Out:
# 0.4865924542648575

# %%
titanic_df["fare_thous"] = titanic_df["Fare"]/1000
titanic_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic_df["Survived"] + titanic_df["Pclass"]
# Out:
# 0      3
# 1      2
# 2      4
# 3      2
# 4      3
#       ..
# 886    2
# 887    2
# 888    3
# 889    2
# 890    3
# Length: 891, dtype: int64

# %%
titanic_df["concat_cabin_embarked"] = titanic_df["Cabin"]+"_"+titanic_df["Embarked"]
titanic_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic_df["country"] = "USA"

# %%
titanic_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# ## Counts and GroupBY Operations

# %%
titanic_df["Sex"].value_counts()
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
titanic_df["Sex"].value_counts(normalize=True)
# Out:
# male      0.647587
# female    0.352413
# Name: Sex, dtype: float64

# %%
titanic_df["Cabin"].value_counts(normalize=True,dropna=False)
# Out:
# None           0.771044
# C23 C25 C27    0.004489
# G6             0.004489
# B96 B98        0.004489
# C22 C26        0.003367
#                  ...
# E34            0.001122
# C7             0.001122
# C54            0.001122
# E36            0.001122
# C148           0.001122
# Name: Cabin, Length: 148, dtype: float64

# %%
# Create un group object
grouped = titanic_df.groupby(["Sex"])
grouped

# %%
grouped.mean()
# Out:
# /var/folders/rl/18cdhwk16tq5svrgh95mgc1h0000gn/T/ipykernel_56102/2755795945.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   grouped.mean()
#         PassengerId  Survived    Pclass        Age     SibSp     Parch  \
# Sex
# female   431.028662  0.742038  2.159236  27.915709  0.694268  0.649682
# male     454.147314  0.188908  2.389948  30.726645  0.429809  0.235702
#
#              Fare  fare_thous
# Sex
# female  44.479818    0.044480
# male    25.523893    0.025524

# %%
grouped[["Survived","Age"]].mean()
# Out:
#         Survived        Age
# Sex
# female  0.742038  27.915709
# male    0.188908  30.726645

# %%
titanic_df.groupby(["Sex"])[["Survived","Age"]].mean()
# Out:
#         Survived        Age
# Sex
# female  0.742038  27.915709
# male    0.188908  30.726645

# %%
agg_df = titanic_df.groupby(["Sex"])[["Survived","Age"]].mean()
agg_df
# Out:
#         Survived        Age
# Sex
# female  0.742038  27.915709
# male    0.188908  30.726645

# %%
agg_df.index
# Out:
# Index(['female', 'male'], dtype='object', name='Sex')

# %%
titanic_df.groupby(["Sex"],as_index=False)[["Survived","Age"]].mean()
# Out:
#       Sex  Survived        Age
# 0  female  0.742038  27.915709
# 1    male  0.188908  30.726645

# %% [markdown]
# ### multiple agg functions

# %%
functions = ["mean","max","count"]
titanic_df.groupby(["Sex"])[["Survived","Age"]].agg(functions)
# Out:
#         Survived                  Age
#             mean max count       mean   max count
# Sex
# female  0.742038   1   314  27.915709  63.0   261
# male    0.188908   1   577  30.726645  80.0   453

# %%
# use different functions across different columns
titanic_df.groupby(["Sex"]).agg({
    "Survived":["mean"],
    "Age":["count","mean"],
    "Fare":["mean","max","min"]
})
# Out:
#         Survived   Age                  Fare
#             mean count       mean       mean       max   min
# Sex
# female  0.742038   261  27.915709  44.479818  512.3292  6.75
# male    0.188908   453  30.726645  25.523893  512.3292  0.00

# %% [markdown]
# ## Plotting

# %%
# barchar
titanic_df.head(10)["Pclass"].plot(kind="bar")
# Out:
# <AxesSubplot: >

# %%
# barchar
titanic_df["Pclass"].value_counts(normalize=True).plot(kind="bar")
# Out:
# <AxesSubplot: >

# %%
# barchar
titanic_df["Pclass"].value_counts(normalize=True).plot(kind="barh")
# Out:
# <AxesSubplot: >

# %%
agg_df = titanic_df.groupby(["Sex"]).mean()
agg_df
# Out:
# /var/folders/rl/18cdhwk16tq5svrgh95mgc1h0000gn/T/ipykernel_56102/2560479715.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   agg_df = titanic_df.groupby(["Sex"]).mean()
#         PassengerId  Survived    Pclass        Age     SibSp     Parch  \
# Sex
# female   431.028662  0.742038  2.159236  27.915709  0.694268  0.649682
# male     454.147314  0.188908  2.389948  30.726645  0.429809  0.235702
#
#              Fare  fare_thous
# Sex
# female  44.479818    0.044480
# male    25.523893    0.025524

# %%
agg_df[["Age","Fare"]].plot(kind="bar")
# Out:
# <AxesSubplot: xlabel='Sex'>

# %%
# Histograms / Density Plots
titanic_df["Age"].plot.hist()
# Out:
# <AxesSubplot: ylabel='Frequency'>

# %%
# Histograms / Density Plots
titanic_df["Age"].plot.hist(
    bins=50,
    color="red",
    figsize=(10,6)
)
# Out:
# <AxesSubplot: ylabel='Frequency'>

# %%
#!pip install scipy
titanic_df["Age"].plot.density()
# Out:
# <AxesSubplot: ylabel='Density'>

# %%
#!pip install scipy

# %%
titanic_df["Age"].plot.density()
